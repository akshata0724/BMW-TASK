# %% [markdown]
# # Load the dataset and print first 10 rows.

# %%
#import pandas libraby
import numpy as np
import pandas as pd

# %%
# Reading csv file with skip 2 rows without header
df = pd.read_csv("C:\\Users\\shubh\\Documents\\5th semester\\pandas\\dataset\\bmw_car_data.csv")
df.head(10)
# Out:
#    ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0   1         X5       xDrive  2019  Electric          Manual       1496
# 1   2         X5  Luxury Line  2016  Electric       Automatic       1496
# 2   3         Z4      M Sport  2012  Electric  Semi-Automatic       4395
# 3   4         X7      M Sport  2013    Hybrid  Semi-Automatic       4395
# 4   5         X7       xDrive  2010  Electric          Manual       2993
# 5   6         X1      M Sport  2012    Petrol          Manual       2993
# 6   7         M3     Standard  2014    Hybrid  Semi-Automatic       4395
# 7   8       320d   Sport Line  2015  Electric  Semi-Automatic       1496
# 8   9         X3   Sport Line  2019  Electric          Manual       1998
# 9  10         i8  Luxury Line  2015    Petrol          Manual       1998
#
#    Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# 0     395.18     492.04         20.48              68.33          Second
# ...

# %% [markdown]
# # Display shape, column names, and data types.

# %%
df.dtypes
# Out:
# ID                        int64
# Model_Name               object
# Variant                  object
# Year                      int64
# Fuel_Type                object
# Transmission             object
# Engine_CC                 int64
# Power_BHP               float64
# Torque_Nm               float64
# Mileage_kmpl            float64
# Price_Ex_Showroom       float64
# Owner_Type               object
# Insurance_Valid_Till      int64
# Location                 object
# Registration_State       object
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission',
#        'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl',
#        'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location',
#        'Registration_State'],
#       dtype='object')

# %%
df.shape
# Out:
# (100000, 15)

# %% [markdown]
# # Check for missing values and count per column.

# %%
#import pandas libraby
import numpy as np
import pandas as pd

# %%
# Reading csv file with skip 2 rows without header
df1 = pd.read_csv("C:\\Users\\shubh\\Documents\\5th semester\\pandas\\dataset\\bmw_car_data.csv")

# %%
df1.isna().sum().sort_values(ascending=True)
# Out:
# ID                      0
# Model_Name              0
# Variant                 0
# Year                    0
# Fuel_Type               0
# Transmission            0
# Engine_CC               0
# Power_BHP               0
# Torque_Nm               0
# Mileage_kmpl            0
# Price_Ex_Showroom       0
# Owner_Type              0
# Insurance_Valid_Till    0
# Location                0
# Registration_State      0
# dtype: int64

# %%
df1
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Filter cars manufactured after 2020.

# %%
df_where = df.where(df['Year'] > 2020)
print(df_where)
# Out:
#             ID Model_Name     Variant    Year Fuel_Type Transmission  \
# 0          NaN        NaN         NaN     NaN       NaN          NaN
# 1          NaN        NaN         NaN     NaN       NaN          NaN
# 2          NaN        NaN         NaN     NaN       NaN          NaN
# 3          NaN        NaN         NaN     NaN       NaN          NaN
# 4          NaN        NaN         NaN     NaN       NaN          NaN
# ...        ...        ...         ...     ...       ...          ...
# 99995      NaN        NaN         NaN     NaN       NaN          NaN
# 99996  99997.0         Z4  Sport Line  2021.0  Electric    Automatic
# 99997      NaN        NaN         NaN     NaN       NaN          NaN
# 99998      NaN        NaN         NaN     NaN       NaN          NaN
# 99999      NaN        NaN         NaN     NaN       NaN          NaN
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # List unique car models and fuel types.

# %%
df['Model_Name'].unique().T
# Out:
# array(['X5', 'Z4', 'X7', 'X1', 'M3', '320d', 'X3', 'i8', 'M4', '520d'],
#       dtype=object)

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Electric', 'Hybrid', 'Petrol', 'Diesel'], dtype=object)

# %% [markdown]
# # Count how many cars per fuel type.

# %%
fuel_type_counts = df['Fuel_Type'].value_counts()
print(fuel_type_counts)
# Out:
# Fuel_Type
# Petrol      25125
# Diesel      25089
# Hybrid      24934
# Electric    24852
# Name: count, dtype: int64

# %% [markdown]
# # Sort dataset by Price_Ex_Showroom descending.

# %%
df.sort_values(ascending=False,by =['Price_Ex_Showroom'])
# Out:
#           ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 86274  86275         X7      M Sport  2024    Petrol          Manual
# 97582  97583         X7      M Sport  2012    Petrol          Manual
# 62468  62469       520d      M Sport  2016    Hybrid  Semi-Automatic
# 94872  94873       320d  Luxury Line  2018    Petrol          Manual
# 57442  57443         M3     Standard  2013    Hybrid  Semi-Automatic
# ...      ...        ...          ...   ...       ...             ...
# 78097  78098       520d       xDrive  2013    Hybrid       Automatic
# 90017  90018       320d   Sport Line  2013  Electric  Semi-Automatic
# 29372  29373         X1     Standard  2012  Electric       Automatic
# 99357  99358       520d      M Sport  2016    Hybrid  Semi-Automatic
# 31867  31868         X3      M Sport  2022    Petrol          Manual
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Filter only Automatic transmission BMWs.

# %%
condition=df['Transmission']=='Automatic'
df[condition]
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 1          2         X5  Luxury Line  2016  Electric    Automatic       1496
# 11        12         X7      M Sport  2019    Hybrid    Automatic       1998
# 14        15         M3     Standard  2017    Hybrid    Automatic       4395
# 16        17         M4     Standard  2022    Hybrid    Automatic       4395
# 20        21         X5   Sport Line  2010    Hybrid    Automatic       1496
# ...      ...        ...          ...   ...       ...          ...        ...
# 99988  99989         X7   Sport Line  2019    Hybrid    Automatic       1496
# 99990  99991         X5       xDrive  2013    Petrol    Automatic       1998
# 99991  99992         X1  Luxury Line  2023    Hybrid    Automatic       1496
# 99996  99997         Z4   Sport Line  2021  Electric    Automatic       1496
# 99997  99998         M4     Standard  2012    Hybrid    Automatic       2993
#
# ...

# %% [markdown]
# # Replace missing mileage values with mean.

# %%
mean_Mileage_kmpl = df['Mileage_kmpl'].mean()
df['Mileage_kmpl'].fillna(mean_Mileage_kmpl,inplace=True)
mean_Mileage_kmpl
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_20800\4115585729.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mileage_kmpl'].fillna(mean_Mileage_kmpl,inplace=True)
# 16.490543700000003

# %%
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Drop rows where Engine_CC is null.

# %%
df_new = df.copy()

# %%
df_new.drop(columns = ['Engine_CC'],inplace=True)
df_new
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# ...

# %% [markdown]
# # Group cars by Model_Name and calculate average price.

# %%
avg = df.groupby('Model_Name')['Price_Ex_Showroom'].mean()
avg
# Out:
# Model_Name
# 320d    85.361262
# 520d    85.270653
# M3      85.090345
# M4      85.223891
# X1      84.612881
# X3      85.528270
# X5      85.401622
# X7      84.835493
# Z4      85.307179
# i8      85.086266
# Name: Price_Ex_Showroom, dtype: float64

# %% [markdown]
# # Create a new column Car_Age = 2025 - Year.

# %%
df_col = df.copy()

# %%
df= df.assign(Car_age=2025-df['Year'])
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Filter cars priced above ₹60 lakh.

# %%
expensive_cars = df(df['Price_Ex_Showroom'] > 60)
expensive_cars
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 expensive_cars = df(df['Price_Ex_Showroom'] > 60)
#       2 expensive_cars
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# # Find top 5 most common cities in the dataset.

# %%
top_cities = df['Location'].value_counts().head(5)
top_cities
# Out:
# Location
# Ahmedabad    12668
# Chennai      12549
# Mumbai       12495
# Bangalore    12492
# Delhi        12478
# Name: count, dtype: int64

# %% [markdown]
# # Plot histogram for mileage.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['Mileage_kmpl'].hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# # Create a bar chart of fuel type vs average power.

# %% [markdown]
# # Apply .loc[] to update fuel type of electric variants.

# %%
df.loc[df['Variant'] == 'Electric','Fuel_Type'] = 'Electric'
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Convert Price_Ex_Showroom from lakh to ₹ value.

# %%
df['Price_Ex_Showroom'] = df['Price_Ex_Showroom'] * 100000
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Find how many cars are older than 10 years.

# %%
df= df.assign(Car_age=2025-df['Year'])
older_car = df[df['Car_age'] > 10]
print(f"Number of cars older than 10 years : {len(older_car)}")
# Out:
# Number of cars older than 10 years : 33320

# %% [markdown]
# # Count of cars by Owner_Type and Transmission.

# %%
count = df.groupby(['Owner_Type','Transmission']).size()
count
# Out:
# Owner_Type      Transmission
# First           Automatic         8487
#                 Manual            8223
#                 Semi-Automatic    8332
# Fourth & Above  Automatic         8256
#                 Manual            8357
#                 Semi-Automatic    8378
# Second          Automatic         8549
#                 Manual            8175
#                 Semi-Automatic    8240
# Third           Automatic         8373
#                 Manual            8248
#                 Semi-Automatic    8382
# dtype: int64

# %% [markdown]
# # Find maximum BHP in diesel cars.

# %%
diesel_cars = df[df['Fuel_Type'] == 'Diesel']
max_BHP = diesel_cars['Power_BHP'].max()
print(f"Maximum BHP in diesel cars: {max_BHP}")
# Out:
# Maximum BHP in diesel cars: 624.98

# %% [markdown]
# # Plot scatter plot of Engine_CC vs Price.

# %% [markdown]
# # Count number of variants per model.

# %%
variants = df.groupby('Model_Name')['Variant'].nunique()
variants.columns = ['Model_Name','Variant']
variants
# Out:
# Model_Name
# 320d    5
# 520d    5
# M3      5
# M4      5
# X1      5
# X3      5
# X5      5
# X7      5
# Z4      5
# i8      5
# Name: Variant, dtype: int64

# %% [markdown]
# # Find car with max and min mileage.

# %%
mileage = df[['Model_Name','Mileage_kmpl']].groupby(['Mileage_kmpl']).agg(['min','max'])
mileage
# Out:
#              Model_Name
#                     min max
# Mileage_kmpl
# 8.00               320d  Z4
# 8.01               320d  i8
# 8.02               320d  i8
# 8.03               320d  i8
# 8.04               320d  i8
# ...                 ...  ..
# 24.96              320d  i8
# 24.97              320d  i8
# 24.98              320d  i8
# 24.99              320d  i8
# 25.00              320d  i8
#
# [1701 rows x 2 columns]

# %% [markdown]
# # Calculate median price per year.

# %%
median_price = df.groupby('Year')['Price_Ex_Showroom'].median()
median_price
# Out:
# Year
# 2010    8599000.0
# 2011    8558500.0
# 2012    8485500.0
# 2013    8493000.0
# 2014    8484000.0
# 2015    8557000.0
# 2016    8546000.0
# 2017    8502000.0
# 2018    8509000.0
# 2019    8485000.0
# 2020    8515000.0
# 2021    8589000.0
# 2022    8526500.0
# 2023    8485000.0
# 2024    8524000.0
# Name: Price_Ex_Showroom, dtype: float64

# %% [markdown]
# # Pivot table with Location vs Fuel_Type.

# %% [markdown]
# # Create a column Is_Luxury (if Price > ₹70L = Yes).

# %%
df['Is_Luxury'] = df['Price_Ex_Showroom'].apply(lambda x: 'Yes' if x > 70 else 'No')
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Remove duplicate rows if any.

# %%
df = df.drop_duplicates()
df
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# # Export filtered data to new CSV.
